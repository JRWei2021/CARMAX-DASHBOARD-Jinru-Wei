# %% [markdown]
# # Data Scraping from Carmax

# %% [markdown]
# ## MA 705 Individual Project

# %% [markdown]
# ### Jinru Wei
# ### B10002915

# %%
import os
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %%
headers = {'User-Agent': 'Safari'}
cars_req = requests.get('https://www.carmax.com/cars', headers = headers)
cars = BeautifulSoup(cars_req.text, 'html.parser')

# %% [markdown]
# ### Extract the link for the 13 types of cars

# %%
cars_links = cars.select('.carousel__slide a')
cartype_links = ['https://www.carmax.com' + link['href']
                for link in cars_links]

cartype_links = cartype_links[0:13]

# %%
cartype_links
# Out:
# ['https://www.carmax.com/cars/sport-utilities',
#  'https://www.carmax.com/cars/pickup-trucks',
#  'https://www.carmax.com/cars/crossovers',
#  'https://www.carmax.com/cars/sedans',
#  'https://www.carmax.com/cars/coupes',
#  'https://www.carmax.com/cars/convertibles',
#  'https://www.carmax.com/cars/luxury-vehicles',
#  'https://www.carmax.com/cars/sports-cars',
#  'https://www.carmax.com/cars/diesel-engines',
#  'https://www.carmax.com/cars/minivans-and-vans',
#  'https://www.carmax.com/cars/hybrids',
#  'https://www.carmax.com/cars/wagons',
#  'https://www.carmax.com/cars/electric-vehicles']

# %% [markdown]
# ### Extract the first part of car information
#
# Year, Make, Model, Price, Milleage, Availability for current store (Norwood)

# %%
year_make = []
model_trim = []
price = []
miles = []
transfer = []
t = 0
car_type = []



for cartype_link in cartype_links:
    car_page_req = requests.get(cartype_link, headers=headers)
    car_page = BeautifulSoup(car_page_req.text, 'html.parser')
    t = t + 1
    car_info1 = car_page.find_all("div", class_="car-tile--content")
    for info in car_info1:
        year_make.append(info.find('span', class_='year-make').text)
        model_trim.append(info.find('span', class_='model-trim').text)
        price.append(info.find('span', class_='price').text)
        miles.append(info.find('span', class_='miles').text)
        transfer.append(info.find('span', class_='transfer').text)
        car_type.append(t)

# %%
# create dataframe for each type
car_type = pd.DataFrame(car_type)
year_make = pd.DataFrame(year_make)
model_trim = pd.DataFrame(model_trim)
price = pd.DataFrame(price)
miles = pd.DataFrame(miles)
transfer = pd.DataFrame(transfer)

year_make = year_make.iloc[:,0].str.split(expand=True, n=1)

# %% [markdown]
# ### Extract the second part of car information
#
# Description, Car Features, Transmission, Color, Interior Color, Average Review

# %%
Description = []
Car_features = []
Transmission = []
Color = []
Interior_Color = []
Average_Review = []

for cartype_link in cartype_links:
    car_page_req = requests.get(cartype_link, headers=headers)
    car_page = BeautifulSoup(car_page_req.text, 'html.parser')
    car_info2 = car_page.find_all("div", class_="car-tile--extra-content")
    for detail in car_info2:
        Car_features.append(car_info2[0].find(class_='car-features').text)
        Description.append(detail.select('span')[1].next_sibling)
        Transmission.append(detail.select('span')[2].next_sibling)
        Color.append(detail.select('span')[3].next_sibling)
        Interior_Color.append(detail.select('span')[4].next_sibling)
        Average_Review.append(detail.select('span')[5].next_sibling)

# %%
# create dataframe for each type
Description = pd.DataFrame(Description)
Car_features = pd.DataFrame(Car_features)
Transmission = pd.DataFrame(Transmission)
Color = pd.DataFrame(Color)
Interior_Color = pd.DataFrame(Interior_Color)
Average_Review = pd.DataFrame(Average_Review)

# %% [markdown]
# ### Extract the second part of car information
#
# Image

# %%
Car_img = []

for cartype_link in cartype_links:
    car_page_req = requests.get(cartype_link, headers=headers)
    car_page = BeautifulSoup(car_page_req.text, 'html.parser')
    car_info3 = car_page.find_all("img", class_="loaded")
    for detail in car_info3:
        Car_img.append(detail.get('src'))

# %%
Cars3 = pd.DataFrame(Car_img)

# %% [markdown]
# ### Merge all the car information dataframes

# %%
carmax = pd.concat([car_type,year_make, model_trim, price,miles,Average_Review,Transmission,Color,Interior_Color,Car_features,transfer,Description, Cars3],axis=1)

# %%
# reset the column names
carmax.columns = ['Type', 'Year', 'Make', 'Model', 'Price', 'Milleage', 'Average Review', 'Transmission', 'Color', 'Interior Color','Features', 'Availability', 'Description', 'Car Image']

# %%
carmax
# Out:
#      Type  Year       Make                        Model    Price Milleage  \
# 0       1  2011      Honda                      CR-V LX  $14,599  126K mi
# 1       1  2013       Jeep        Grand Cherokee Laredo  $23,998   76K mi
# 2       1  2017      Dodge                  Journey SXT  $18,998   82K mi
# 3       1  2015  Chevrolet                    Tahoe LTZ  $46,998   67K mi
# 4       1  2019       Jeep           Grand Cherokee SRT  $70,998   26K mi
# ..    ...   ...        ...                          ...      ...      ...
# 292    13  2021      Tesla  Model 3 Standard Range Plus  $51,998    4K mi
# 293    13  2019      Tesla          Model 3 Performance  $55,998   19K mi
# 294    13  2018      Tesla           Model 3 Long Range  $50,998   11K mi
# 295    13  2021      Tesla          Model 3 Performance  $69,998    2K mi
# 296    13  2021      Tesla  Model 3 Standard Range Plus  $53,998    4K mi
#
#                                        Average Review  \
# 0     (4.506849315068493 reviews)\r\n
# 1     (4.451612903225806 reviews)\r\n
# 2    (3.8095238095238098 reviews)\r\n
# 3     (4.388888888888889 reviews)\r\n
# 4     (4.714285714285714 reviews)\r\n
# ..                                                ...
# 292                   (0 reviews)\r\n
# 293                   (0 reviews)\r\n
# 294                   (0 reviews)\r\n
# 295                   (0 reviews)\r\n
# 296                   (0 reviews)\r\n
#
#                           Transmission                          Color  \
# 0    Automatic\r\n                       Blue\r\n
# 1    Automatic\r\n                       Gray\r\n
# 2    Automatic\r\n                       Gray\r\n
# 3    Automatic\r\n                      Black\r\n
# 4    Automatic\r\n                        Red\r\n
# ..                                 ...                            ...
# 292  Automatic\r\n                       Gray\r\n
# 293  Automatic\r\n                       Gray\r\n
# 294  Automatic\r\n                        Red\r\n
# 295  Automatic\r\n                      White\r\n
# 296  Automatic\r\n                        Red\r\n
#
#                      Interior Color  \
# 0      Gray\r\n
# 1     Black\r\n
# 2     Black\r\n
# 3     Black\r\n
# 4     Brown\r\n
# ..                              ...
# 292   Black\r\n
# 293   Black\r\n
# 294   Black\r\n
# 295   Black\r\n
# 296   Black\r\n
#
#                                               Features  \
# 0    4WD/AWD, Auxiliary Audio Input, Cruise Control...
# 1    4WD/AWD, Auxiliary Audio Input, Cruise Control...
# 2    4WD/AWD, Auxiliary Audio Input, Cruise Control...
# 3    4WD/AWD, Auxiliary Audio Input, Cruise Control...
# 4    4WD/AWD, Auxiliary Audio Input, Cruise Control...
# ..                                                 ...
# 292  4WD/AWD, Leatherette Seats, Parking Sensors, R...
# 293  4WD/AWD, Leatherette Seats, Parking Sensors, R...
# 294  4WD/AWD, Leatherette Seats, Parking Sensors, R...
# 295  4WD/AWD, Leatherette Seats, Parking Sensors, R...
# 296  4WD/AWD, Leatherette Seats, Parking Sensors, R...
#
#                                    Availability  \
# 0    Available at your store CarMax Norwood, MA
# 1    Available at your store CarMax Norwood, MA
# 2    Available at your store CarMax Norwood, MA
# 3    Available at your store CarMax Norwood, MA
# 4    Available at your store CarMax Norwood, MA
# ..                                          ...
# 292      $99 Shipping from CarMax Waterbury, CT
# 293         Only available at CarMax Easton, PA
# 294         Only available at CarMax Easton, PA
# 295            Coming soon to CarMax Albany, NY
# 296            Coming soon to CarMax Easton, PA
#
#                                            Description  \
# 0     Used 2011 Honda CR-V LX for sale - $14,599, 1...
# 1     Used 2013 Jeep Grand Cherokee Laredo for sale...
# 2     Used 2017 Dodge Journey SXT for sale - $18,99...
# 3     Used 2015 Chevrolet Tahoe LTZ for sale - $46,...
# 4     Used 2019 Jeep Grand Cherokee SRT for sale - ...
# ..                                                 ...
# 292   Used 2021 Tesla Model 3 Standard Range Plus f...
# 293   Used 2019 Tesla Model 3 Performance for sale ...
# 294   Used 2018 Tesla Model 3 Long Range for sale -...
# 295   Used 2021 Tesla Model 3 Performance for sale ...
# 296   Used 2021 Tesla Model 3 Standard Range Plus f...
#
#                                              Car Image
# 0    https://media-service.carmax.com/img/vehicles/...
# 1    https://media-service.carmax.com/img/vehicles/...
# 2    https://media-service.carmax.com/img/vehicles/...
# 3    https://media-service.carmax.com/img/vehicles/...
# 4    https://media-service.carmax.com/img/vehicles/...
# ..                                                 ...
# 292  https://media-service.carmax.com/img/vehicles/...
# 293  https://media-service.carmax.com/img/vehicles/...
# 294  https://media-service.carmax.com/img/vehicles/...
# 295  https://media-service.carmax.com/img/vehicles/...
# 296  https://media-service.carmax.com/img/vehicles/...
#
# [297 rows x 14 columns]

# %% [markdown]
# Delete redundant strings in the dataset

# %%
carmax['Color'] = carmax['Color'].str.replace('\r\n','')
carmax['Interior Color'] = carmax['Interior Color'].str.replace('\r\n','')
carmax['Transmission'] = carmax['Transmission'].str.replace('\r\n','')
carmax['Average Review'] = carmax['Average Review'].str.replace('\r\n','')
carmax['Average Review'] = carmax['Average Review'].str.replace('(','')
carmax['Average Review'] = carmax['Average Review'].str.replace(')','')
carmax['Average Review'] = carmax['Average Review'].str.replace(' reviews','')

# %%
carmax['Type'] =  carmax['Type'].replace(1,'SUV')
carmax['Type'] =  carmax['Type'].replace(2,'Truck')
carmax['Type'] =  carmax['Type'].replace(3,'Crossover')
carmax['Type'] =  carmax['Type'].replace(4,'Sedan')
carmax['Type'] =  carmax['Type'].replace(5,'Coupe')
carmax['Type'] =  carmax['Type'].replace(6,'Convertible')
carmax['Type'] =  carmax['Type'].replace(7,'Luxury')
carmax['Type'] =  carmax['Type'].replace(8,'Sport Car')
carmax['Type'] =  carmax['Type'].replace(9,'Diesel Engine')
carmax['Type'] =  carmax['Type'].replace(10,'Van')
carmax['Type'] =  carmax['Type'].replace(11,'Hybrid')
carmax['Type'] =  carmax['Type'].replace(12,'Wagon')
carmax['Type'] =  carmax['Type'].replace(13,'Electric Vehicle')

# %%
carmax
# Out:
#                  Type  Year       Make                        Model    Price  \
# 0                 SUV  2011      Honda                      CR-V LX  $14,599
# 1                 SUV  2013       Jeep        Grand Cherokee Laredo  $23,998
# 2                 SUV  2017      Dodge                  Journey SXT  $18,998
# 3                 SUV  2015  Chevrolet                    Tahoe LTZ  $46,998
# 4                 SUV  2019       Jeep           Grand Cherokee SRT  $70,998
# ..                ...   ...        ...                          ...      ...
# 292  Electric Vehicle  2021      Tesla  Model 3 Standard Range Plus  $51,998
# 293  Electric Vehicle  2019      Tesla          Model 3 Performance  $55,998
# 294  Electric Vehicle  2018      Tesla           Model 3 Long Range  $50,998
# 295  Electric Vehicle  2021      Tesla          Model 3 Performance  $69,998
# 296  Electric Vehicle  2021      Tesla  Model 3 Standard Range Plus  $53,998
#
#     Milleage                      Average Review  \
# 0    126K mi   4.506849315068493
# 1     76K mi   4.451612903225806
# 2     82K mi  3.8095238095238098
# 3     67K mi   4.388888888888889
# 4     26K mi   4.714285714285714
# ..       ...                                 ...
# 292    4K mi                   0
# 293   19K mi                   0
# 294   11K mi                   0
# 295    2K mi                   0
# 296    4K mi                   0
#
#                       Transmission                      Color  \
# 0    Automatic                       Blue
# 1    Automatic                       Gray
# 2    Automatic                       Gray
# 3    Automatic                      Black
# 4    Automatic                        Red
# ..                             ...                        ...
# 292  Automatic                       Gray
# 293  Automatic                       Gray
# 294  Automatic                        Red
# 295  Automatic                      White
# 296  Automatic                        Red
#
#                  Interior Color  \
# 0      Gray
# 1     Black
# 2     Black
# 3     Black
# 4     Brown
# ..                          ...
# 292   Black
# 293   Black
# 294   Black
# 295   Black
# 296   Black
#
#                                               Features  \
# 0    4WD/AWD, Auxiliary Audio Input, Cruise Control...
# 1    4WD/AWD, Auxiliary Audio Input, Cruise Control...
# 2    4WD/AWD, Auxiliary Audio Input, Cruise Control...
# 3    4WD/AWD, Auxiliary Audio Input, Cruise Control...
# 4    4WD/AWD, Auxiliary Audio Input, Cruise Control...
# ..                                                 ...
# 292  4WD/AWD, Leatherette Seats, Parking Sensors, R...
# 293  4WD/AWD, Leatherette Seats, Parking Sensors, R...
# 294  4WD/AWD, Leatherette Seats, Parking Sensors, R...
# 295  4WD/AWD, Leatherette Seats, Parking Sensors, R...
# 296  4WD/AWD, Leatherette Seats, Parking Sensors, R...
#
#                                    Availability  \
# 0    Available at your store CarMax Norwood, MA
# 1    Available at your store CarMax Norwood, MA
# 2    Available at your store CarMax Norwood, MA
# 3    Available at your store CarMax Norwood, MA
# 4    Available at your store CarMax Norwood, MA
# ..                                          ...
# 292      $99 Shipping from CarMax Waterbury, CT
# 293         Only available at CarMax Easton, PA
# 294         Only available at CarMax Easton, PA
# 295            Coming soon to CarMax Albany, NY
# 296            Coming soon to CarMax Easton, PA
#
#                                            Description  \
# 0     Used 2011 Honda CR-V LX for sale - $14,599, 1...
# 1     Used 2013 Jeep Grand Cherokee Laredo for sale...
# 2     Used 2017 Dodge Journey SXT for sale - $18,99...
# 3     Used 2015 Chevrolet Tahoe LTZ for sale - $46,...
# 4     Used 2019 Jeep Grand Cherokee SRT for sale - ...
# ..                                                 ...
# 292   Used 2021 Tesla Model 3 Standard Range Plus f...
# 293   Used 2019 Tesla Model 3 Performance for sale ...
# 294   Used 2018 Tesla Model 3 Long Range for sale -...
# 295   Used 2021 Tesla Model 3 Performance for sale ...
# 296   Used 2021 Tesla Model 3 Standard Range Plus f...
#
#                                              Car Image
# 0    https://media-service.carmax.com/img/vehicles/...
# 1    https://media-service.carmax.com/img/vehicles/...
# 2    https://media-service.carmax.com/img/vehicles/...
# 3    https://media-service.carmax.com/img/vehicles/...
# 4    https://media-service.carmax.com/img/vehicles/...
# ..                                                 ...
# 292  https://media-service.carmax.com/img/vehicles/...
# 293  https://media-service.carmax.com/img/vehicles/...
# 294  https://media-service.carmax.com/img/vehicles/...
# 295  https://media-service.carmax.com/img/vehicles/...
# 296  https://media-service.carmax.com/img/vehicles/...
#
# [297 rows x 14 columns]

# %% [markdown]
# Export the csv file

# %%
carmax.to_csv('carmax2.csv',index=False)
